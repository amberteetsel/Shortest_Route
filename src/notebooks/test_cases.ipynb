# %% [markdown]
# # Shortest Route: Finding the most efficient driving routes between New York City landmarks

# %% [markdown]
# ## Description of Approach

# %% [markdown]
# ##### **Approach**
# - We selected NYC because it's a group member's former home
# - Nodes were defined by selection iconic NYC locations (ex. Times Square, Rockefeller Center, Empire State Building, etc.)
# - The maps in this notebook were built using `folium`
# - For both base and rush hour scenarios, we used Google Maps data. The dataset included information on peak travel times, but we opted to use a model instead to show increase congestion. The model applies a multiple between 1 and 3 to each edge.
#
# ##### **Assumptions**
# - The time from node A to node B is the same as the time from node B to node A

# %% [markdown]
# ## Graph Structure & Algorithm Implementation

# %% [markdown]
# We chose to represent our graph with ........
#
# Dijkstra's Algorithm was implemented by ........
#
# Design choices include setting the `folium` map to highlight the shortest path in red, and making the backgroup map of NYC more simplistic/subtle to increase contrast

# %% [markdown]
# ## Code-Based Verification

# %% [markdown]
# ### Import Libraries, Functions, Data

# %%
import sys
import os
import json
import folium
import random
import numpy as np

project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from modules.graph import Graph
from modules.mapGraph import build_graph_from_json
from modules.displayMap import build_graph_mappings
from modules.simulate import sim_traffic_data

# %%
with open('manhattan_driving_distances.json', 'r') as f:
    loaded_dict = json.load(f)

# %% [markdown]
# ### Base Case: Average Traffic Conditions

# %%
start_node = "Battery Park / South Ferry"
end_node = "Rockefeller Center"

# %% [markdown]
# #### Without Uncertainty

# %%
metric = "avg"
distances = sim_traffic_data(loaded_dict, start_node, metric, False)[1]
g = sim_traffic_data(loaded_dict, start_node, metric, False)[0]

print(f"Average Travel Time from \033[1m{start_node}\033[0m to \033[1m{end_node}\033[0m: {round(distances[1],2)} min")

build_graph_mappings(loaded_dict, start_node, end_node, metric, False)
# Out:
# Average Travel Time from Battery Park / South Ferry to Rockefeller Center: 30.53 min
# Shortest path names: ['Battery Park / South Ferry', 'Washington Square Park', 'Union Square', 'Flatiron / Madison Sq Park', 'Empire State Building', 'Bryant Park / NYPL', 'Rockefeller Center']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51fbc73b499c74badee49b2b86c435f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 210px; height: 110px;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         box-shadow: 3px 3px 6px rgba(0,0,0,0.2);
#         &quot;&gt;
#         &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;●&lt;/span&gt; Shortest Path Node&lt;br&gt;
#         &lt;span style=&quot;color:gray;&quot;&gt;●&lt;/span&gt; Other Nodes&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;━&lt;/span&gt; Shortest Path Edge (time in minutes)&lt;br&gt;
#         &lt;span style=&quot;color:blue;&quot;&gt;━&lt;/span&gt; Other Edges (time in minutes)&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51fbc73b499c74badee49b2b86c435f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51fbc73b499c74badee49b2b86c435f0 = L.map(
#                 &quot;map_51fbc73b499c74badee49b2b86c435f0&quot;,
#                 {
#                     center: [40.75, -73.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f529688a7435a372738de73dd5b3a12 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f529688a7435a372738de73dd5b3a12.addTo(map_51fbc73b499c74badee49b2b86c435f0);
#
#
#             var poly_line_7f399b43b4ebfacb5d67fe059d98fa06 = L.polyline(
#                 [[40.757, -73.98597], [40.75926, -73.97996]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_51fbc73b499c74badee49b2b86c435f0);
#
#
#             var marker_3b9d735bb204234ad4fde0c52c7602e5 = L.marker(
#                 [40.758129999999994, -73.98296500000001],
#                 {
# }
#             ).addTo(map_51fbc73b499c74badee49b2b86c435f0);
#
#
#             var div_icon_d7f6188f87d9b47702f804325350be1a = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n                                            padding: 2px 4px; border-radius: 3px;\n                                            border: 1px solid blue;\n                                            white-space: nowrap;\&quot;\u003e\n                                    2.45 min\n                                \u003c/div\u003e\n                            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_3b9d735bb204234ad4fde0c52c7602e5.setIcon(div_icon_d7f6188f87d9b47702f804325350be1a);
#
#
#             var poly_line_8fa96d8687b9fcc19d8cea9471bc1759 = L.polyline(
#                 [[40.757, -73.98597], [40.75361, -73.98417]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_51fbc73b499c74badee49b2b86c435f0);
#
#
#             var marker_daa67c1b59bcc546b2cf650bc26c1b5a = L.marker(
#                 [40.755305, -73.98507000000001],
#                 {
# }
#             ).addTo(map_51fbc73b499c74badee49b2b86c435f0);
#
#
#             var div_icon_0c80e003001a0bddab485a94ec01ced7 = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n

# %% [markdown]
# #### With Uncertainty

# %%
distances = sim_traffic_data(loaded_dict, start_node, metric, True)[1]
g = sim_traffic_data(loaded_dict, start_node, metric, True)[0]

print(f"Average Travel Time from \033[1m{start_node}\033[0m to \033[1m{end_node}\033[0m: {round(distances[1],2)} min")

if round(distances[1],2) == float('inf'):
    print(f"Road Closure: Unable to drive from {start_node} to {end_node}")
else:
    build_graph_mappings(loaded_dict, start_node, end_node, metric, True)
# Out:
# Average Travel Time from Battery Park / South Ferry to Rockefeller Center: 117.24 min
# Shortest path names: ['Battery Park / South Ferry', 'Washington Square Park', 'Chelsea Market', 'Union Square', 'Flatiron / Madison Sq Park', 'Empire State Building', 'Bryant Park / NYPL', 'Rockefeller Center']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_258beece5b8c71ece3889e4747b933c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 210px; height: 110px;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         box-shadow: 3px 3px 6px rgba(0,0,0,0.2);
#         &quot;&gt;
#         &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;●&lt;/span&gt; Shortest Path Node&lt;br&gt;
#         &lt;span style=&quot;color:gray;&quot;&gt;●&lt;/span&gt; Other Nodes&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;━&lt;/span&gt; Shortest Path Edge (time in minutes)&lt;br&gt;
#         &lt;span style=&quot;color:blue;&quot;&gt;━&lt;/span&gt; Other Edges (time in minutes)&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_258beece5b8c71ece3889e4747b933c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_258beece5b8c71ece3889e4747b933c2 = L.map(
#                 &quot;map_258beece5b8c71ece3889e4747b933c2&quot;,
#                 {
#                     center: [40.75, -73.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df52b651103cac9c196993b26a73109f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df52b651103cac9c196993b26a73109f.addTo(map_258beece5b8c71ece3889e4747b933c2);
#
#
#             var poly_line_5002b8aa33648fc0acd2a4b75653866f = L.polyline(
#                 [[40.757, -73.98597], [40.75926, -73.97996]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_258beece5b8c71ece3889e4747b933c2);
#
#
#             var marker_885a315a9e75eebb3cbd9db01bf1f7ff = L.marker(
#                 [40.758129999999994, -73.98296500000001],
#                 {
# }
#             ).addTo(map_258beece5b8c71ece3889e4747b933c2);
#
#
#             var div_icon_24bf1b89a1436d18a19abd2b5c44f00a = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n                                            padding: 2px 4px; border-radius: 3px;\n                                            border: 1px solid blue;\n                                            white-space: nowrap;\&quot;\u003e\n                                    inf min\n                                \u003c/div\u003e\n                            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_885a315a9e75eebb3cbd9db01bf1f7ff.setIcon(div_icon_24bf1b89a1436d18a19abd2b5c44f00a);
#
#
#             var poly_line_8b7dafcfaf4488ba7835e24e36b610e1 = L.polyline(
#                 [[40.757, -73.98597], [40.75361, -73.98417]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_258beece5b8c71ece3889e4747b933c2);
#
#
#             var marker_222c45f79fa537806508d2fc83b5a1ef = L.marker(
#                 [40.755305, -73.98507000000001],
#                 {
# }
#             ).addTo(map_258beece5b8c71ece3889e4747b933c2);
#
#
#             var div_icon_0fd03db9ad6ee5559068056f06809fd9 = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n

# %% [markdown]
# ### Rush Hour Scenario: Peak Traffic Conditions

# %% [markdown]
# #### Without Uncertainty

# %%
start_node = "Battery Park / South Ferry"
end_node = "Rockefeller Center"
metric = "peak"
distances = sim_traffic_data(loaded_dict, start_node, metric, False)[1]
g = sim_traffic_data(loaded_dict, start_node, metric, False)[0]

print(f"Average Travel Time from \033[1m{start_node}\033[0m to \033[1m{end_node}\033[0m: {round(distances[1],2)} min")

build_graph_mappings(loaded_dict, start_node, end_node, metric, False)
# Out:
# Average Travel Time from Battery Park / South Ferry to Rockefeller Center: 66.23 min
# Shortest path names: ['Battery Park / South Ferry', 'Washington Square Park', 'Union Square', 'Flatiron / Madison Sq Park', 'Empire State Building', 'Grand Central Terminal', 'Rockefeller Center']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea869dbeef5d28ca12adada189690983 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 210px; height: 110px;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         box-shadow: 3px 3px 6px rgba(0,0,0,0.2);
#         &quot;&gt;
#         &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;●&lt;/span&gt; Shortest Path Node&lt;br&gt;
#         &lt;span style=&quot;color:gray;&quot;&gt;●&lt;/span&gt; Other Nodes&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;━&lt;/span&gt; Shortest Path Edge (time in minutes)&lt;br&gt;
#         &lt;span style=&quot;color:blue;&quot;&gt;━&lt;/span&gt; Other Edges (time in minutes)&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea869dbeef5d28ca12adada189690983&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea869dbeef5d28ca12adada189690983 = L.map(
#                 &quot;map_ea869dbeef5d28ca12adada189690983&quot;,
#                 {
#                     center: [40.75, -73.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f4538bfe5a1e08f125670a1574c5ece = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f4538bfe5a1e08f125670a1574c5ece.addTo(map_ea869dbeef5d28ca12adada189690983);
#
#
#             var poly_line_2ed2d32150df06aa1f0e80d94c65e3bf = L.polyline(
#                 [[40.757, -73.98597], [40.75926, -73.97996]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ea869dbeef5d28ca12adada189690983);
#
#
#             var marker_04177e58e9b5beb8068195d3d1d900d7 = L.marker(
#                 [40.758129999999994, -73.98296500000001],
#                 {
# }
#             ).addTo(map_ea869dbeef5d28ca12adada189690983);
#
#
#             var div_icon_2dcb9588006d6967ce5bd3d8495dc69c = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n                                            padding: 2px 4px; border-radius: 3px;\n                                            border: 1px solid blue;\n                                            white-space: nowrap;\&quot;\u003e\n                                    7.89 min\n                                \u003c/div\u003e\n                            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_04177e58e9b5beb8068195d3d1d900d7.setIcon(div_icon_2dcb9588006d6967ce5bd3d8495dc69c);
#
#
#             var poly_line_1200330fe16b9baa0d15009c361062a7 = L.polyline(
#                 [[40.757, -73.98597], [40.75361, -73.98417]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_ea869dbeef5d28ca12adada189690983);
#
#
#             var marker_36d05d525cb26b28715e63f761a3a077 = L.marker(
#                 [40.755305, -73.98507000000001],
#                 {
# }
#             ).addTo(map_ea869dbeef5d28ca12adada189690983);
#
#
#             var div_icon_434a01525d7dae34e71bbd6eb4079426 = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n

# %% [markdown]
# #### With Uncertainty

# %%
distances = sim_traffic_data(loaded_dict, start_node, metric, True)[1]
g = sim_traffic_data(loaded_dict, start_node, metric, True)[0]

print(f"Average Travel Time from \033[1m{start_node}\033[0m to \033[1m{end_node}\033[0m: {round(distances[1],2)} min")

if round(distances[1],2) == float('inf'):
    print(f"Road Closure: Unable to drive from {start_node} to {end_node}")
else:
    build_graph_mappings(loaded_dict, start_node, end_node, metric, True)
# Out:
# Average Travel Time from Battery Park / South Ferry to Rockefeller Center: 116.77 min
# Shortest path names: ['Battery Park / South Ferry', 'Washington Square Park', 'Union Square', 'Flatiron / Madison Sq Park', 'Empire State Building', 'Grand Central Terminal', 'Rockefeller Center']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60c72d032b435ef7813fbe44afe9727f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 50px; left: 50px; width: 210px; height: 110px;
#         background-color: white;
#         border:2px solid grey;
#         z-index:9999;
#         font-size:14px;
#         padding: 10px;
#         box-shadow: 3px 3px 6px rgba(0,0,0,0.2);
#         &quot;&gt;
#         &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;●&lt;/span&gt; Shortest Path Node&lt;br&gt;
#         &lt;span style=&quot;color:gray;&quot;&gt;●&lt;/span&gt; Other Nodes&lt;br&gt;
#         &lt;span style=&quot;color:red;&quot;&gt;━&lt;/span&gt; Shortest Path Edge (time in minutes)&lt;br&gt;
#         &lt;span style=&quot;color:blue;&quot;&gt;━&lt;/span&gt; Other Edges (time in minutes)&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60c72d032b435ef7813fbe44afe9727f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60c72d032b435ef7813fbe44afe9727f = L.map(
#                 &quot;map_60c72d032b435ef7813fbe44afe9727f&quot;,
#                 {
#                     center: [40.75, -73.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d385d823c0d1320cf22f1dd670bdfe78 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d385d823c0d1320cf22f1dd670bdfe78.addTo(map_60c72d032b435ef7813fbe44afe9727f);
#
#
#             var poly_line_f832a06b9c368d4a2429dd77d574f81b = L.polyline(
#                 [[40.757, -73.98597], [40.75926, -73.97996]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_60c72d032b435ef7813fbe44afe9727f);
#
#
#             var marker_3bb8d7f8fe9c142942da1cffcc2536c7 = L.marker(
#                 [40.758129999999994, -73.98296500000001],
#                 {
# }
#             ).addTo(map_60c72d032b435ef7813fbe44afe9727f);
#
#
#             var div_icon_416f45a133e9964a1745562f855db821 = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n                                            padding: 2px 4px; border-radius: 3px;\n                                            border: 1px solid blue;\n                                            white-space: nowrap;\&quot;\u003e\n                                    40.47 min\n                                \u003c/div\u003e\n                            &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_3bb8d7f8fe9c142942da1cffcc2536c7.setIcon(div_icon_416f45a133e9964a1745562f855db821);
#
#
#             var poly_line_b50588d4b2ddffbeacbff3dff0d00d35 = L.polyline(
#                 [[40.757, -73.98597], [40.75361, -73.98417]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_60c72d032b435ef7813fbe44afe9727f);
#
#
#             var marker_18c797bf31482d2e143e177b9ac8f028 = L.marker(
#                 [40.755305, -73.98507000000001],
#                 {
# }
#             ).addTo(map_60c72d032b435ef7813fbe44afe9727f);
#
#
#             var div_icon_dfa8276eb52bdf4929d191a0f9dbb071 = L.divIcon({
#   &quot;html&quot;: &quot;\n                                \u003cdiv style=\&quot;font-size: 9px; color: blue;\n                                            background-color: rgba(255,255,255,0.7);\n

# %% [markdown]
# ## Discussion & Analysis

# %% [markdown]
# ##### **Route**
# Due to the shape of the graph (layout of selected NYC landmarks), the shortest path from Battery Park to Rockefeller Center is almost always the same despite the scenario <br>
# - Battery Park / South Ferry $\rightarrow$ Washington Square Park $\rightarrow$ Union Square $\rightarrow$ Flatiron / Madison Sq Park $\rightarrow$ Empire State Building $\rightarrow$ Grand Central Terminal $\rightarrow$ Rockefeller Center <br>
#
# However, road closures can cause a deviation in the path. For example, when we added uncertainty to the average traffic scenario, the route between Union Square and Washington Square park was blocked off. As a result, the shortest path diverted to Chelsea Market before continuing as usual.
#
# ##### **Uncertainty**
#
# Uncertainty can lead to a large increase in travel time. For example, at peak traffic (without uncertainty) the time between Battery Park and Rockefeller Center was 66.23 minutes. After factoring in uncertainty, the time increased to 116.77 minutes (+76%)! Also, as noted above, road closures due to uncertainty can change the shortest path as well as add travel time.
#
# ##### **Interpreting Results**
#
# ##### **Assumptions & Limitations**
# Our results are conditioned on the initial selection of nodes. There are of course many different ways to travel to each of the NYC landmarks; a road closure would not actually mean you can't make it to a certain destination. We also assumed that travel time from node A to node B was the same as for node B to node A. In reality this would not be true given NYC's many one-way streets and varying traffic patterns.
