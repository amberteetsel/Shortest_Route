# %%
import sys
import os
import json

project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# ## Importing libraries and necessary functions

# %%
from modules.graph import Graph

# %%
with open('manhattan_driving_distances.json', 'r') as f:
    loaded_dict = json.load(f)

# %%
# average traffic time
g = Graph(len(loaded_dict['nodes']))

for key in loaded_dict['nodes'].keys():
    g.add_vertex_data(int(key), loaded_dict['nodes'][key]["name"])

for i in loaded_dict["pairwise"].keys():
    for j in loaded_dict["pairwise"][i].keys():
        g.add_edge(int(i), int(j), loaded_dict["pairwise"][i][j]['avg_time_min'])

# %%
distances = g.dijkstra("Times Square")

# %%
for i, d in enumerate(distances):
    print(f"Distance from Times Square to {g.vertex_data[i]} during average traffic hours: {d}")
# Out:
# Distance from Times Square to Times Square during average traffic hours: 4.31
# Distance from Times Square to Rockefeller Center during average traffic hours: 5.68
# Distance from Times Square to Bryant Park / NYPL during average traffic hours: 2.55
# Distance from Times Square to Grand Central Terminal during average traffic hours: 3.71
# Distance from Times Square to Empire State Building during average traffic hours: 0
# Distance from Times Square to Flatiron / Madison Sq Park during average traffic hours: 3.86
# Distance from Times Square to Union Square during average traffic hours: 5.949999999999999
# Distance from Times Square to Chelsea Market during average traffic hours: 11.09
# Distance from Times Square to Washington Square Park during average traffic hours: 9.87
# Distance from Times Square to Battery Park / South Ferry during average traffic hours: 24.85
